# %%
import kaggle_benchmarks as kbench
print(kbench.llms.keys())
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a7f97369-3d12-4297-a8e1-4bcac3ea91d7'>
#   <div id="c0632ea7-7c0b-4b8d-95c8-a473fb517299" data-root-id="a7f97369-3d12-4297-a8e1-4bcac3ea91d7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f3aec780-5d44-4077-82be-681c03755ce9":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"f6d81a36-f254-48f4-bdee-c0328bbe4510","attributes":{"notifications":{"type":"object","name":"Notifications","id":"4088f3d9-ff7a-4eec-bbe4-876bfc16d3af"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a7f97369-3d12-4297-a8e1-4bcac3ea91d7"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"b261b6be-e1fd-4b6e-a37e-557adfa0b92f","attributes":{"plot_id":"a7f97369-3d12-4297-a8e1-4bcac3ea91d7","comm_id":"70b5bc46f00248a99fd873c5b18e8fd6","client_comm_id":"875aea931a2a4ab78d74fa69e2fd21fd"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"f3aec780-5d44-4077-82be-681c03755ce9","roots":{"a7f97369-3d12-4297-a8e1-4bcac3ea91d7":"c0632ea7-7c0b-4b8d-95c8-a473fb517299"},"root_ids":["a7f97369-3d12-4297-a8e1-4bcac3ea91d7"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# dict_keys(['anthropic/claude-haiku-4-5@20251001', 'anthropic/claude-opus-4-1@20250805', 'anthropic/claude-opus-4-5@20251101', 'anthropic/claude-opus-4-6@default', 'anthropic/claude-opus-4-7@default', 'anthropic/claude-sonnet-4-5@20250929', 'anthropic/claude-sonnet-4-6@default', 'anthropic/claude-sonnet-4@20250514', 'deepseek-ai/deepseek-r1-0528', 'deepseek-ai/deepseek-v3.1', 'deepseek-ai/deepseek-v3.2', 'google/gemini-2.0-flash', 'google/gemini-2.0-flash-lite', 'google/gemini-2.5-flash', 'google/gemini-2.5-pro', 'google/gemini-3-flash-preview', 'google/gemini-3.1-flash-lite-preview', 'google/gemini-3.1-pro-preview', 'google/gemma-3-12b', 'google/gemma-3-1b', 'google/gemma-3-27b', 'google/gemma-3-4b', 'google/gemma-4-26b-a4b', 'google/gemma-4-31b', 'openai/gpt-5.4-2026-03-05', 'openai/gpt-5.4-mini-2026-03-17', 'openai/gpt-5.4-nano-2026-03-17', 'openai/gpt-oss-120b', 'openai/gpt-oss-20b', 'qwen/qwen3-235b-a22b-instruct-2507', 'qwen/qwen3-coder-480b-a35b-instruct', 'qwen/qwen3-next-80b-a3b-instruct', 'qwen/qwen3-next-80b-a3b-thinking', 'zai/glm-5'])

# %%
# !apt-get update && apt-get install -y git
# Out:
# Get:1 http://deb.debian.org/debian trixie InRelease [140 kB]
# Get:2 http://deb.debian.org/debian trixie-updates InRelease [47.3 kB]
# Get:3 http://deb.debian.org/debian-security trixie-security InRelease [43.4 kB]
# Get:4 http://deb.debian.org/debian trixie/main amd64 Packages [9671 kB]
# Get:5 http://deb.debian.org/debian trixie-updates/main amd64 Packages [5412 B]
# Get:6 http://deb.debian.org/debian-security trixie-security/main amd64 Packages [127 kB]
# Fetched 10.0 MB in 1s (6894 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   git-man less libcbor0.10 libcurl3t64-gnutls liberror-perl libfido2-1
#   libgdbm-compat4t64 libldap-common libldap2 libnghttp2-14 libnghttp3-9
#   libngtcp2-16 libngtcp2-crypto-gnutls8 libperl5.40 libpsl5t64 librtmp1
#   libsasl2-2 libsasl2-modules libsasl2-modules-db libssh2-1t64 libxmuu1
#   openssh-client patch perl perl-modules-5.40 publicsuffix xauth
# Suggested packages:
#   gettext-base git-doc git-email git-gui gitk gitweb git-cvs git-mediawiki
#   git-svn sensible-utils libsasl2-modules-gssapi-mit
#   | libsasl2-modules-gssapi-heimdal libsasl2-modules-ldap libsasl2-modules-otp
#   libsasl2-modules-sql keychain libpam-ssh monkeysphere ssh-askpass ed
#   diffutils-doc perl-doc libterm-readline-gnu-perl
#   | libterm-readline-perl-perl make libtap-harness-archive-perl
# The following NEW packages will be installed:
#   git git-man less libcbor0.10 libcurl3t64-gnutls liberror-perl libfido2-1
#   libgdbm-compat4t64 libldap-common libldap2 libnghttp2-14 libnghttp3-9
#   libngtcp2-16 libngtcp2-crypto-gnutls8 libperl5.40 libpsl5t64 librtmp1
#   libsasl2-2 libsasl2-modules libsasl2-modules-db libssh2-1t64 libxmuu1
#   openssh-client patch perl perl-modules-5.40 publicsuffix xauth
# 0 upgraded, 28 newly installed, 0 to remove and 17 not upgraded.
# Need to get 21.9 MB of archives.
# After this operation, 115 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian trixie/main amd64 less amd64 668-1 [161 kB]
# Get:2 http://deb.debian.org/debian trixie/main amd64 libcbor0.10 amd64 0.10.2-2 [28.3 kB]
# Get:3 http://deb.debian.org/debian trixie/main amd64 libfido2-1 amd64 1.15.0-1+b1 [78.7 kB]
# Get:4 http://deb.debian.org/debian-security trixie-security/main amd64 openssh-client amd64 1:10.0p1-7+deb13u2 [986 kB]
# Get:5 http://deb.debian.org/debian trixie/main amd64 perl-modules-5.40 all 5.40.1-6 [3019 kB]
# Get:6 http://deb.debian.org/debian trixie/main amd64 libgdbm-compat4t64 amd64 1.24-2 [50.3 kB]
# Get:7 http://deb.debian.org/debian trixie/main amd64 libperl5.40 amd64 5.40.1-6 [4341 kB]
# Get:8 http://deb.debian.org/debian trixie/main amd64 perl amd64 5.40.1-6 [267 kB]
# Get:9 http://deb.debian.org/debian trixie/main amd64 libsasl2-modules-db amd64 2.1.28+dfsg1-9 [19.8 kB]
# Get:10 http://deb.debian.org/debian trixie/main amd64 libsasl2-2 amd64 2.1.28+dfsg1-9 [57.5 kB]
# Get:11 http://deb.debian.org/debian trixie/main amd64 libldap2 amd64 2.6.10+dfsg-1 [194 kB]
# Get:12 http://deb.debian.org/debian trixie/main amd64 libnghttp2-14 amd64 1.64.0-1.1 [76.0 kB]
# Get:13 http://deb.debian.org/debian trixie/main amd64 libnghttp3-9 amd64 1.8.0-1 [67.7 kB]
# Get:14 http://deb.debian.org/debian-security trixie-security/main amd64 libngtcp2-16 amd64 1.11.0-1+deb13u1 [132 kB]
# Get:15 http://deb.debian.org/debian-security trixie-security/main amd64 libngtcp2-crypto-gnutls8 amd64 1.11.0-1+deb13u1 [29.5 kB]
# Get:16 http://deb.debian.org/debian trixie/main amd64 libpsl5t64 amd64 0.21.2-1.1+b1 [57.2 kB]
# Get:17 http://deb.debian.org/debian trixie/main amd64 librtmp1 amd64 2.4+20151223.gitfa8646d.1-2+b5 [58.8 kB]
# Get:18 http://deb.debian.org/debian trixie/main amd64 libssh2-1t64 amd64 1.11.1-1 [245 kB]
# Get:19 http://deb.debian.org/debian trixie/main amd64 libcurl3t64-gnutls amd64 8.14.1-2+deb13u2 [383 kB]
# Get:20 http://deb.debian.org/debian trixie/main amd64 liberror-perl all 0.17030-1 [26.9 kB]
# Get:21 http://deb.debian.org/debian trixie/main amd64 git-man all 1:2.47.3-0+deb13u1 [2205 kB]
# Get:22 http://deb.debian.org/debian trixie/main amd64 git amd64 1:2.47.3-0+deb13u1 [8862 kB]
# Get:23 http://deb.debian.org/debian trixie/main amd64 libldap-common all 2.6.10+dfsg-1 [35.1 kB]
# Get:24 http://deb.debian.org/debian trixie/main amd64 libsasl2-modules amd64 2.1.28+dfsg1-9 [66.7 kB]
# Get:25 http://deb.debian.org/debian trixie/main amd64 libxmuu1 amd64 2:1.1.3-3+b4 [21.9 kB]
# Get:26 http://deb.debian.org/debian trixie/main amd64 patch amd64 2.8-2 [134 kB]
# Get:27 http://deb.debian.org/debian trixie/main amd64 publicsuffix all 20250328.1952-0.1 [296 kB]
# Get:28 http://deb.debian.org/debian trixie/main amd64 xauth amd64 1:1.1.2-1.1 [35.9 kB]
# Fetched 21.9 MB in 0s (71.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 79, <STDIN> line 28.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC entries checked: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.40.1 /usr/local/share/perl/5.40.1 /usr/lib/x86_64-linux-gnu/perl5/5.40 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.40 /usr/share/perl/5.40 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 8, <STDIN> line 28.)
# debconf: falling back to frontend: Teletype
# Selecting previously unselected package less.
# (Reading database ... 10921 files and directories currently installed.)
# Preparing to unpack .../00-less_668-1_amd64.deb ...
# Unpacking less (668-1) ...
# Selecting previously unselected package libcbor0.10:amd64.
# Preparing to unpack .../01-libcbor0.10_0.10.2-2_amd64.deb ...
# Unpacking libcbor0.10:amd64 (0.10.2-2) ...
# Selecting previously unselected package libfido2-1:amd64.
# Preparing to unpack .../02-libfido2-1_1.15.0-1+b1_amd64.deb ...
# Unpacking libfido2-1:amd64 (1.15.0-1+b1) ...
# Selecting previously unselected package openssh-client.
# Preparing to unpack .../03-openssh-client_1%3a10.0p1-7+deb13u2_amd64.deb ...
# Unpacking openssh-client (1:10.0p1-7+deb13u2) ...
# Selecting previously unselected package perl-modules-5.40.
# Preparing to unpack .../04-perl-modules-5.40_5.40.1-6_all.deb ...
# Unpacking perl-modules-5.40 (5.40.1-6) ...
# Selecting previously unselected package libgdbm-compat4t64:amd64.
# Preparing to unpack .../05-libgdbm-compat4t64_1.24-2_amd64.deb ...
# Unpacking libgdbm-compat4t64:amd64 (1.24-2) ...
# Selecting previously unselected package libperl5.40:amd64.
# Preparing to unpack .../06-libperl5.40_5.40.1-6_amd64.deb ...
# Unpacking libperl5.40:amd64 (5.40.1-6) ...
# Selecting previously unselected package perl.
# Preparing to unpack .../07-perl_5.40.1-6_amd64.deb ...
# Unpacking perl (5.40.1-6) ...
# Selecting previously unselected package libsasl2-modules-db:amd64.
# Preparing to unpack .../08-libsasl2-modules-db_2.1.28+dfsg1-9_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.28+dfsg1-9) ...
# Selecting previously unselected package libsasl2-2:amd64.
# Preparing to unpack .../09-libsasl2-2_2.1.28+dfsg1-9_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.28+dfsg1-9) ...
# Selecting previously unselected package libldap2:amd64.
# Preparing to unpack .../10-libldap2_2.6.10+dfsg-1_amd64.deb ...
# Unpacking libldap2:amd64 (2.6.10+dfsg-1) ...
# Selecting previously unselected package libnghttp2-14:amd64.
# Preparing to unpack .../11-libnghttp2-14_1.64.0-1.1_amd64.deb ...
# Unpacking libnghttp2-14:amd64 (1.64.0-1.1) ...
# Selecting previously unselected package libnghttp3-9:amd64.
# Preparing to unpack .../12-libnghttp3-9_1.8.0-1_amd64.deb ...
# Unpacking libnghttp3-9:amd64 (1.8.0-1) ...
# Selecting previously unselected package libngtcp2-16:amd64.
# Preparing to unpack .../13-libngtcp2-16_1.11.0-1+deb13u1_amd64.deb ...
# Unpacking libngtcp2-16:amd64 (1.11.0-1+deb13u1) ...
# Selecting previously unselected package libngtcp2-crypto-gnutls8:amd64.
# Preparing to unpack .../14-libngtcp2-crypto-gnutls8_1.11.0-1+deb13u1_amd64.deb ...
# Unpacking libngtcp2-crypto-gnutls8:amd64 (1.11.0-1+deb13u1) ...
# Selecting previously unselected package libpsl5t64:amd64.
# Preparing to unpack .../15-libpsl5t64_0.21.2-1.1+b1_amd64.deb ...
# Unpacking libpsl5t64:amd64 (0.21.2-1.1+b1) ...
# Selecting previously unselected package librtmp1:amd64.
# Preparing to unpack .../16-librtmp1_2.4+20151223.gitfa8646d.1-2+b5_amd64.deb ...
# Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b5) ...
# Selecting previously unselected package libssh2-1t64:amd64.
# Preparing to unpack .../17-libssh2-1t64_1.11.1-1_amd64.deb ...
# Unpacking libssh2-1t64:amd64 (1.11.1-1) ...
# Selecting previously unselected package libcurl3t64-gnutls:amd64.
# Preparing to unpack .../18-libcurl3t64-gnutls_8.14.1-2+deb13u2_amd64.deb ...
# Unpacking libcurl3t64-gnutls:amd64 (8.14.1-2+deb13u2) ...
# Selecting previously unselected package liberror-perl.
# Preparing to unpack .../19-liberror-perl_0.17030-1_all.deb ...
# Unpacking liberror-perl (0.17030-1) ...
# Selecting previously unselected package git-man.
# Preparing to unpack .../20-git-man_1%3a2.47.3-0+deb13u1_all.deb ...
# Unpacking git-man (1:2.47.3-0+deb13u1) ...
# Selecting previously unselected package git.
# Preparing to unpack .../21-git_1%3a2.47.3-0+deb13u1_amd64.deb ...
# Unpacking git (1:2.47.3-0+deb13u1) ...
# Selecting previously unselected package libldap-common.
# Preparing to unpack .../22-libldap-common_2.6.10+dfsg-1_all.deb ...
# Unpacking libldap-common (2.6.10+dfsg-1) ...
# Selecting previously unselected package libsasl2-modules:amd64.
# Preparing to unpack .../23-libsasl2-modules_2.1.28+dfsg1-9_amd64.deb ...
# Unpacking libsasl2-modules:amd64 (2.1.28+dfsg1-9) ...
# Selecting previously unselected package libxmuu1:amd64.
# Preparing to unpack .../24-libxmuu1_2%3a1.1.3-3+b4_amd64.deb ...
# Unpacking libxmuu1:amd64 (2:1.1.3-3+b4) ...
# Selecting previously unselected package patch.
# Preparing to unpack .../25-patch_2.8-2_amd64.deb ...
# Unpacking patch (2.8-2) ...
# Selecting previously unselected package publicsuffix.
# Preparing to unpack .../26-publicsuffix_20250328.1952-0.1_all.deb ...
# Unpacking publicsuffix (20250328.1952-0.1) ...
# Selecting previously unselected package xauth.
# Preparing to unpack .../27-xauth_1%3a1.1.2-1.1_amd64.deb ...
# Unpacking xauth (1:1.1.2-1.1) ...
# Setting up libgdbm-compat4t64:amd64 (1.24-2) ...
# Setting up libcbor0.10:amd64 (0.10.2-2) ...
# Setting up libsasl2-modules:amd64 (2.1.28+dfsg1-9) ...
# Setting up libpsl5t64:amd64 (0.21.2-1.1+b1) ...
# Setting up libnghttp2-14:amd64 (1.64.0-1.1) ...
# Setting up less (668-1) ...
# Setting up libldap-common (2.6.10+dfsg-1) ...
# Setting up libsasl2-modules-db:amd64 (2.1.28+dfsg1-9) ...
# Setting up librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b5) ...
# Setting up patch (2.8-2) ...
# Setting up libsasl2-2:amd64 (2.1.28+dfsg1-9) ...
# Setting up libnghttp3-9:amd64 (1.8.0-1) ...
# Setting up perl-modules-5.40 (5.40.1-6) ...
# Setting up git-man (1:2.47.3-0+deb13u1) ...
# Setting up libngtcp2-16:amd64 (1.11.0-1+deb13u1) ...
# Setting up libssh2-1t64:amd64 (1.11.1-1) ...
# Setting up libfido2-1:amd64 (1.15.0-1+b1) ...
# Setting up publicsuffix (20250328.1952-0.1) ...
# Setting up libldap2:amd64 (2.6.10+dfsg-1) ...
# Setting up libxmuu1:amd64 (2:1.1.3-3+b4) ...
# Setting up libngtcp2-crypto-gnutls8:amd64 (1.11.0-1+deb13u1) ...
# Setting up openssh-client (1:10.0p1-7+deb13u2) ...
# Created symlink '/etc/systemd/user/sockets.target.wants/ssh-agent.socket' → '/usr/lib/systemd/user/ssh-agent.socket'.
# Setting up libcurl3t64-gnutls:amd64 (8.14.1-2+deb13u2) ...
# Setting up libperl5.40:amd64 (5.40.1-6) ...
# Setting up perl (5.40.1-6) ...
# Setting up xauth (1:1.1.2-1.1) ...
# Setting up liberror-perl (0.17030-1) ...
# Setting up git (1:2.47.3-0+deb13u1) ...
# Processing triggers for libc-bin (2.41-12+deb13u1) ...

# %%
# !git clone https://github.com/Gl12321/web_parse_agent
# Out:
# Cloning into 'web_parse_agent'...
# remote: Enumerating objects: 197, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 197 (delta 55), reused 186 (delta 44), pack-reused 0 (from 0)
# Receiving objects: 100% (197/197), 37.15 KiB | 1.03 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# !pip install -r web_parse_agent/requirements.txt
# Out:
# Collecting langchain>=0.3.0 (from -r web_parse_agent/requirements.txt (line 1))
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-openai>=0.2.0 (from -r web_parse_agent/requirements.txt (line 2))
#   Downloading langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core>=0.3.0 (from -r web_parse_agent/requirements.txt (line 3))
#   Downloading langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain-community>=0.3.0 (from -r web_parse_agent/requirements.txt (line 4))
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langgraph>=0.2.0 (from -r web_parse_agent/requirements.txt (line 5))
#   Downloading langgraph-1.1.9-py3-none-any.whl.metadata (8.0 kB)
# Collecting langchain-text-splitters>=0.3.0 (from -r web_parse_agent/requirements.txt (line 6))
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting crawl4ai>=0.3.0 (from -r web_parse_agent/requirements.txt (line 7))
#   Downloading crawl4ai-0.8.6-py3-none-any.whl.metadata (55 kB)
# Requirement already satisfied: pydantic>=2.0.0 in /benchmarks/.venv/lib/python3.11/site-packages (from -r web_parse_agent/requirements.txt (line 8)) (2.12.5)
# Collecting pydantic-settings>=2.0.0 (from -r web_parse_agent/requirements.txt (line 9))
#   Downloading pydantic_settings-2.14.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dotenv>=1.0.0 in /benchmarks/.venv/lib/python3.11/site-packages (from -r web_parse_agent/requirements.txt (line 10)) (1.2.1)
# Collecting sqlalchemy>=2.0.0 (from -r web_parse_agent/requirements.txt (line 11))
#   Downloading sqlalchemy-2.0.49-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting html2text>=2024.0.0 (from -r web_parse_agent/requirements.txt (line 12))
#   Downloading html2text-2025.4.15-py3-none-any.whl.metadata (4.1 kB)
# Collecting fastapi>=0.115.0 (from -r web_parse_agent/requirements.txt (line 13))
#   Downloading fastapi-0.136.1-py3-none-any.whl.metadata (28 kB)
# Collecting uvicorn>=0.32.0 (from -r web_parse_agent/requirements.txt (line 14))
#   Downloading uvicorn-0.46.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.10 (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3))
#   Downloading langchain_protocol-0.0.12-py3-none-any.whl.metadata (1.8 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3))
#   Downloading langsmith-0.7.36-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /benchmarks/.venv/lib/python3.11/site-packages (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /benchmarks/.venv/lib/python3.11/site-packages (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /benchmarks/.venv/lib/python3.11/site-packages (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /benchmarks/.venv/lib/python3.11/site-packages (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3))
#   Downloading uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5))
#   Downloading langgraph_checkpoint-4.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5))
#   Downloading langgraph_prebuilt-1.0.11-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5))
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5))
#   Downloading xxhash-3.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /benchmarks/.venv/lib/python3.11/site-packages (from pydantic>=2.0.0->-r web_parse_agent/requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /benchmarks/.venv/lib/python3.11/site-packages (from pydantic>=2.0.0->-r web_parse_agent/requirements.txt (line 8)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /benchmarks/.venv/lib/python3.11/site-packages (from pydantic>=2.0.0->-r web_parse_agent/requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /benchmarks/.venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (3.0.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5))
#   Downloading ormsgpack-1.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /benchmarks/.venv/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5)) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5))
#   Downloading orjson-3.11.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3))
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /benchmarks/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3))
#   Downloading zstandard-0.25.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /benchmarks/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5)) (4.12.0)
# Requirement already satisfied: certifi in /benchmarks/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /benchmarks/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /benchmarks/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5)) (3.11)
# Requirement already satisfied: h11>=0.16 in /benchmarks/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph>=0.2.0->-r web_parse_agent/requirements.txt (line 5)) (0.16.0)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai>=0.2.0->-r web_parse_agent/requirements.txt (line 2))
#   Downloading openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai>=0.2.0->-r web_parse_agent/requirements.txt (line 2))
#   Downloading tiktoken-0.12.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai>=0.2.0->-r web_parse_agent/requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai>=0.2.0->-r web_parse_agent/requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: sniffio in /benchmarks/.venv/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai>=0.2.0->-r web_parse_agent/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai>=0.2.0->-r web_parse_agent/requirements.txt (line 2)) (4.67.1)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.2.0->-r web_parse_agent/requirements.txt (line 2))
#   Downloading regex-2026.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading langchain_classic-1.0.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading aiohttp-3.13.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in /benchmarks/.venv/lib/python3.11/site-packages (from langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4)) (2.3.5)
# Requirement already satisfied: greenlet>=1 in /benchmarks/.venv/lib/python3.11/site-packages (from sqlalchemy>=2.0.0->-r web_parse_agent/requirements.txt (line 11)) (3.3.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /benchmarks/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4)) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading yarl-1.23.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /benchmarks/.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /benchmarks/.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.0->-r web_parse_agent/requirements.txt (line 3)) (2.6.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /benchmarks/.venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community>=0.3.0->-r web_parse_agent/requirements.txt (line 4)) (1.1.0)
# Collecting aiofiles>=24.1.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: aiosqlite~=0.20 in /benchmarks/.venv/lib/python3.11/site-packages (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (0.22.1)
# Collecting lxml~=5.3 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Collecting unclecode-litellm==1.81.13 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading unclecode_litellm-1.81.13-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: pillow>=10.4 in /benchmarks/.venv/lib/python3.11/site-packages (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: playwright>=1.49.0 in /benchmarks/.venv/lib/python3.11/site-packages (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (1.57.0)
# Collecting patchright>=1.49.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading patchright-1.58.2-py3-none-manylinux1_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4~=4.12 in /benchmarks/.venv/lib/python3.11/site-packages (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (4.14.3)
# Collecting playwright-stealth>=2.0.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading playwright_stealth-2.0.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting rank-bm25~=0.2 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting snowballstemmer~=2.2 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pyOpenSSL>=25.3.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading pyopenssl-26.1.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: psutil>=6.1.1 in /benchmarks/.venv/lib/python3.11/site-packages (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (7.1.3)
# Collecting nltk>=3.9.1 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting rich>=13.9.4 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting cssselect>=1.2.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading cssselect-1.4.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting fake-useragent>=2.0.3 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: click>=8.1.7 in /benchmarks/.venv/lib/python3.11/site-packages (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (8.3.1)
# Collecting chardet>=5.2.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading chardet-7.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.4 kB)
# Collecting brotli>=1.1.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading brotli-1.2.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Collecting humanize>=4.10.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading humanize-4.15.0-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: lark>=1.2.2 in /benchmarks/.venv/lib/python3.11/site-packages (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (1.3.1)
# Collecting alphashape>=1.3.1 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading alphashape-1.3.1-py2.py3-none-any.whl.metadata (18 kB)
# Collecting shapely>=2.0.0 (from crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading shapely-2.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.8 kB)
# Collecting fastuuid>=0.13.0 (from unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading fastuuid-0.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /benchmarks/.venv/lib/python3.11/site-packages (from unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (6.11.0)
# Collecting tokenizers (from unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /benchmarks/.venv/lib/python3.11/site-packages (from unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /benchmarks/.venv/lib/python3.11/site-packages (from unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (4.25.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /benchmarks/.venv/lib/python3.11/site-packages (from beautifulsoup4~=4.12->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (2.8)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /benchmarks/.venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.23.0->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /benchmarks/.venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.23.0->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /benchmarks/.venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.23.0->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (0.30.0)
# Collecting starlette>=0.46.0 (from fastapi>=0.115.0->-r web_parse_agent/requirements.txt (line 13))
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi>=0.115.0->-r web_parse_agent/requirements.txt (line 13))
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting click-log>=0.3.2 (from alphashape>=1.3.1->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading click_log-0.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting trimesh>=3.9.8 (from alphashape>=1.3.1->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading trimesh-4.12.1-py3-none-any.whl.metadata (13 kB)
# Collecting networkx>=2.5 (from alphashape>=1.3.1->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting rtree>=0.9.7 (from alphashape>=1.3.1->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting scipy>=1.0.0 (from alphashape>=1.3.1->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting h2<5,>=3 (from httpx[http2]>=0.27.2->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: zipp>=0.5 in /benchmarks/.venv/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /benchmarks/.venv/lib/python3.11/site-packages (from jinja2>=3.1.2->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: joblib in /benchmarks/.venv/lib/python3.11/site-packages (from nltk>=3.9.1->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: pyee<14,>=13 in /benchmarks/.venv/lib/python3.11/site-packages (from patchright>=1.49.0->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (13.0.0)
# Collecting cryptography<48,>=46.0.0 (from pyOpenSSL>=25.3.0->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: cffi>=2.0.0 in /benchmarks/.venv/lib/python3.11/site-packages (from cryptography<48,>=46.0.0->pyOpenSSL>=25.3.0->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: pycparser in /benchmarks/.venv/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography<48,>=46.0.0->pyOpenSSL>=25.3.0->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (2.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /benchmarks/.venv/lib/python3.11/site-packages (from rich>=13.9.4->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /benchmarks/.venv/lib/python3.11/site-packages (from rich>=13.9.4->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /benchmarks/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7)) (0.1.2)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading huggingface_hub-1.12.0-py3-none-any.whl.metadata (14 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting typer (from huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading typer-0.24.2-py3-none-any.whl.metadata (15 kB)
# Collecting shellingham>=1.3.0 (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->unclecode-litellm==1.81.13->crawl4ai>=0.3.0->-r web_parse_agent/requirements.txt (line 7))
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading langchain-1.2.15-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.3.2-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 8.4 MB/s  0:00:00
# Downloading langgraph-1.1.9-py3-none-any.whl (173 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph_checkpoint-4.0.2-py3-none-any.whl (51 kB)
# Downloading langgraph_prebuilt-1.0.11-py3-none-any.whl (36 kB)
# Downloading langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Downloading langsmith-0.7.36-py3-none-any.whl (381 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Downloading langchain_openai-1.2.1-py3-none-any.whl (98 kB)
# Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.1 MB/s  0:00:00
# Downloading tiktoken-0.12.0-cp311-cp311-manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.3 MB/s  0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.0 MB/s  0:00:00
# Downloading pydantic_settings-2.14.0-py3-none-any.whl (60 kB)
# Downloading sqlalchemy-2.0.49-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 78.1 MB/s  0:00:00
# Downloading aiohttp-3.13.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 66.6 MB/s  0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.4-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.5 MB/s  0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (102 kB)
# Downloading crawl4ai-0.8.6-py3-none-any.whl (501 kB)
# Downloading unclecode_litellm-1.81.13-py3-none-any.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 62.0 MB/s  0:00:00 eta 0:00:01
# Downloading lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 58.8 MB/s  0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Downloading xxhash-3.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Downloading html2text-2025.4.15-py3-none-any.whl (34 kB)
# Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
# Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading alphashape-1.3.1-py2.py3-none-any.whl (13 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 60.1 MB/s  0:00:00
# Downloading chardet-7.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.4/883.4 kB 29.1 MB/s  0:00:00
# Downloading click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Downloading cssselect-1.4.0-py3-none-any.whl (18 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Downloading fastuuid-0.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (279 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (231 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading humanize-4.15.0-py3-none-any.whl (132 kB)
# Downloading langchain_protocol-0.0.12-py3-none-any.whl (6.6 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 62.8 MB/s  0:00:00
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.5 MB/s  0:00:00
# Downloading orjson-3.11.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Downloading ormsgpack-1.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Downloading patchright-1.58.2-py3-none-manylinux1_x86_64.whl (46.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 57.3 MB/s  0:00:00m0:00:0100:01
# Downloading playwright_stealth-2.0.3-py3-none-any.whl (34 kB)
# Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (210 kB)
# Downloading pyopenssl-26.1.0-py3-none-any.whl (58 kB)
# Downloading cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 54.1 MB/s  0:00:00
# Downloading regex-2026.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (799 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.8/799.8 kB 23.3 MB/s  0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (507 kB)
# Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 55.3 MB/s  0:00:00m0:00:0100:01
# Downloading shapely-2.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 86.0 MB/s  0:00:00
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
# Downloading trimesh-4.12.1-py3-none-any.whl (741 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 741.0/741.0 kB 24.4 MB/s  0:00:00
# Downloading zstandard-0.25.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 61.4 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 79.7 MB/s  0:00:00
# Downloading huggingface_hub-1.12.0-py3-none-any.whl (646 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.8/646.8 kB 16.7 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 50.0 MB/s  0:00:00
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading typer-0.24.2-py3-none-any.whl (55 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: snowballstemmer, brotli, zstandard, xxhash, uvicorn, uuid-utils, typing-inspect, trimesh, sqlalchemy, shellingham, shapely, scipy, rtree, regex, rank-bm25, propcache, ormsgpack, orjson, networkx, multidict, marshmallow, lxml, langchain-protocol, jsonpatch, hyperframe, humanize, httpx-sse, html2text, hpack, hf-xet, fsspec, frozenlist, filelock, fastuuid, fake-useragent, cssselect, click-log, chardet, annotated-doc, aiohappyeyeballs, aiofiles, yarl, tiktoken, starlette, rich, requests-toolbelt, patchright, nltk, h2, dataclasses-json, cryptography, alphashape, aiosignal, typer, pyOpenSSL, pydantic-settings, playwright-stealth, openai, langsmith, langgraph-sdk, fastapi, aiohttp, langchain-core, huggingface-hub, tokenizers, langgraph-checkpoint, langchain-text-splitters, langchain-openai, unclecode-litellm, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, crawl4ai, langchain
#   Attempting uninstall: aiofiles╺━━━━━━━━━━━━━━━━━━━ 38/75 [annotated-doc]ocol]
#     Found existing installation: aiofiles 22.1.0━━━━━━━━━━━━━━ 38/75 [annotated-doc]
#     Uninstalling aiofiles-22.1.0:╺━━━━━━━━━━━━━━━━━━━ 38/75 [annotated-doc]
#       Successfully uninstalled aiofiles-22.1.0━━━━━━━━━━━━━━━━ 38/75 [annotated-doc]
#   Attempting uninstall: openai━━━━━━━╸━━━━━━━━━━ 56/75 [playwright-stealth]
#     Found existing installation: openai 2.12.0m━━━━━━━━━━ 56/75 [playwright-stealth]
#     Uninstalling openai-2.12.0:━━━━━━━╺━━━━━━━━━ 57/75 [openai]stealth]
#       Successfully uninstalled openai-2.12.090m╺━━━━━━━━━ 57/75 [openai]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75/75 [langchain]angchain]rawl4ai]-community]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ypy-websocket 0.8.4 requires aiofiles<23,>=22.1.0, but you have aiofiles 25.1.0 which is incompatible.
# Successfully installed aiofiles-25.1.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 alphashape-1.3.1 annotated-doc-0.0.4 brotli-1.2.0 chardet-7.4.3 click-log-0.4.0 crawl4ai-0.8.6 cryptography-47.0.0 cssselect-1.4.0 dataclasses-json-0.6.7 fake-useragent-2.2.0 fastapi-0.136.1 fastuuid-0.14.0 filelock-3.29.0 frozenlist-1.8.0 fsspec-2026.3.0 h2-4.3.0 hf-xet-1.4.3 hpack-4.1.0 html2text-2025.4.15 httpx-sse-0.4.3 huggingface-hub-1.12.0 humanize-4.15.0 hyperframe-6.1.0 jsonpatch-1.33 langchain-1.2.15 langchain-classic-1.0.4 langchain-community-0.4.1 langchain-core-1.3.2 langchain-openai-1.2.1 langchain-protocol-0.0.12 langchain-text-splitters-1.1.2 langgraph-1.1.9 langgraph-checkpoint-4.0.2 langgraph-prebuilt-1.0.11 langgraph-sdk-0.3.13 langsmith-0.7.36 lxml-5.4.0 marshmallow-3.26.2 multidict-6.7.1 networkx-3.6.1 nltk-3.9.4 openai-2.32.0 orjson-3.11.8 ormsgpack-1.12.2 patchright-1.58.2 playwright-stealth-2.0.3 propcache-0.4.1 pyOpenSSL-26.1.0 pydantic-settings-2.14.0 rank-bm25-0.2.2 regex-2026.4.4 requests-toolbelt-1.0.0 rich-15.0.0 rtree-1.4.1 scipy-1.17.1 shapely-2.1.2 shellingham-1.5.4 snowballstemmer-2.2.0 sqlalchemy-2.0.49 starlette-1.0.0 tiktoken-0.12.0 tokenizers-0.22.2 trimesh-4.12.1 typer-0.24.2 typing-inspect-0.9.0 unclecode-litellm-1.81.13 uuid-utils-0.14.1 uvicorn-0.46.0 xxhash-3.7.0 yarl-1.23.0 zstandard-0.25.0

# %%
# !playwright install chromium --with-deps
# Out:
# Installing dependencies...
# Hit:1 http://deb.debian.org/debian trixie InRelease
# Hit:2 http://deb.debian.org/debian trixie-updates InRelease
# Hit:3 http://deb.debian.org/debian-security trixie-security InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libasound2t64 is already the newest version (1.2.14-1).
# libatk-bridge2.0-0t64 is already the newest version (2.56.2-1+deb13u1).
# libatk1.0-0t64 is already the newest version (2.56.2-1+deb13u1).
# libatspi2.0-0t64 is already the newest version (2.56.2-1+deb13u1).
# libcairo2 is already the newest version (1.18.4-1+b1).
# libcups2t64 is already the newest version (2.4.10-3+deb13u2).
# libdbus-1-3 is already the newest version (1.16.2-2).
# libdrm2 is already the newest version (2.4.124-2).
# libgbm1 is already the newest version (25.0.7-2).
# libglib2.0-0t64 is already the newest version (2.84.4-3~deb13u2).
# libnspr4 is already the newest version (2:4.36-1).
# libnss3 is already the newest version (2:3.110-1+deb13u1).
# libpango-1.0-0 is already the newest version (1.56.3-1).
# libx11-6 is already the newest version (2:1.8.12-1).
# libxcb1 is already the newest version (1.17.0-2+b1).
# libxcomposite1 is already the newest version (1:0.4.6-1).
# libxdamage1 is already the newest version (1:1.1.6-1+b2).
# libxext6 is already the newest version (2:1.3.4-1+b3).
# libxfixes3 is already the newest version (1:6.0.0-2+b4).
# libxkbcommon0 is already the newest version (1.7.0-2).
# libxrandr2 is already the newest version (2:1.5.4-1+b3).
# xvfb is already the newest version (2:21.1.16-1.3+deb13u1).
# fonts-noto-color-emoji is already the newest version (2.051-0+deb13u1).
# fonts-unifont is already the newest version (1:15.1.01-1).
# libfontconfig1 is already the newest version (2.15.0-2.3).
# libfreetype6 is already the newest version (2.13.3+dfsg-1+deb13u1).
# libfreetype6 set to manually installed.
# xfonts-scalable is already the newest version (1:1.0.3-1.3).
# fonts-liberation is already the newest version (1:2.1.5-3).
# fonts-ipafont-gothic is already the newest version (00303-23).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-freefont-ttf is already the newest version (20211204+svn4273-2).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# Downloading Chromium 143.0.7499.4 (playwright build v1200) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1200/chromium-linux.zip
# (node:1074) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 164.7 MiB [                    ] 0% 0.0s164.7 MiB [                    ] 0% 211.6s164.7 MiB [                    ] 0% 221.7s164.7 MiB [                    ] 0% 559.2s164.7 MiB [                    ] 0% 480.0s164.7 MiB [                    ] 0% 639.0s164.7 MiB [                    ] 0% 569.3s164.7 MiB [                    ] 0% 518.0s164.7 MiB [                    ] 0% 479.5s164.7 MiB [                    ] 0% 449.6s164.7 MiB [                    ] 0% 425.6s164.7 MiB [                    ] 0% 384.7s164.7 MiB [                    ] 0% 385.3s164.7 MiB [                    ] 0% 371.8s164.7 MiB [                    ] 0% 359.5s164.7 MiB [                    ] 0% 346.7s164.7 MiB [                    ] 0% 335.6s164.7 MiB [                    ] 0% 310.0s164.7 MiB [                    ] 0% 304.6s164.7 MiB [                    ] 0% 273.5s164.7 MiB [                    ] 0% 249.9s164.7 MiB [                    ] 0% 238.0s164.7 MiB [                    ] 0% 221.5s164.7 MiB [                    ] 0% 208.3s164.7 MiB [                    ] 0% 196.4s164.7 MiB [                    ] 0% 185.8s164.7 MiB [                    ] 0% 173.2s164.7 MiB [                    ] 0% 165.0s164.7 MiB [                    ] 0% 152.6s164.7 MiB [                    ] 0% 141.9s164.7 MiB [                    ] 0% 133.0s164.7 MiB [                    ] 0% 122.9s164.7 MiB [                    ] 0% 115.2s164.7 MiB [                    ] 0% 108.5s164.7 MiB [                    ] 0% 101.7s164.7 MiB [                    ] 0% 94.9s164.7 MiB [                    ] 0% 89.1s164.7 MiB [                    ] 1% 83.3s164.7 MiB [                    ] 1% 77.8s164.7 MiB [                    ] 1% 72.0s164.7 MiB [                    ] 1% 66.8s164.7 MiB [                    ] 1% 61.9s164.7 MiB [                    ] 1% 57.5s164.7 MiB [                    ] 1% 53.4s164.7 MiB [                    ] 1% 49.8s164.7 MiB [                    ] 2% 46.5s164.7 MiB [                    ] 2% 43.3s164.7 MiB [=                   ] 2% 40.2s164.7 MiB [=                   ] 2% 37.0s164.7 MiB [=                   ] 3% 34.5s164.7 MiB [=                   ] 3% 31.8s164.7 MiB [=                   ] 3% 29.6s164.7 MiB [=                   ] 3% 27.3s164.7 MiB [=                   ] 4% 25.3s164.7 MiB [=                   ] 4% 23.9s164.7 MiB [=                   ] 4% 23.0s164.7 MiB [=                   ] 5% 22.2s164.7 MiB [=                   ] 5% 21.0s164.7 MiB [=                   ] 5% 20.0s164.7 MiB [=                   ] 6% 19.2s164.7 MiB [=                   ] 6% 18.0s164.7 MiB [=                   ] 6% 17.5s164.7 MiB [=                   ] 7% 17.1s164.7 MiB [==                  ] 7% 16.3s164.7 MiB [==                  ] 7% 15.9s164.7 MiB [==                  ] 8% 15.1s164.7 MiB [==                  ] 8% 14.8s164.7 MiB [==                  ] 9% 14.2s164.7 MiB [==                  ] 9% 13.9s164.7 MiB [==                  ] 9% 13.5s164.7 MiB [==                  ] 10% 13.2s164.7 MiB [==                  ] 10% 12.9s164.7 MiB [==                  ] 10% 12.4s164.7 MiB [==                  ] 11% 12.2s164.7 MiB [==                  ] 11% 12.1s164.7 MiB [==                  ] 11% 11.9s164.7 MiB [==                  ] 11% 11.6s164.7 MiB [==                  ] 12% 11.5s164.7 MiB [===                 ] 12% 11.3s164.7 MiB [===                 ] 13% 10.9s164.7 MiB [===                 ] 13% 10.6s164.7 MiB [===                 ] 13% 10.5s164.7 MiB [===                 ] 14% 10.3s164.7 MiB [===                 ] 14% 10.2s164.7 MiB [===                 ] 14% 10.0s164.7 MiB [===                 ] 15% 9.8s164.7 MiB [===                 ] 15% 9.6s164.7 MiB [===                 ] 16% 9.5s164.7 MiB [===                 ] 16% 9.3s164.7 MiB [===                 ] 16% 9.2s164.7 MiB [===                 ] 16% 9.1s164.7 MiB [===                 ] 17% 8.9s164.7 MiB [====                ] 17% 8.7s164.7 MiB [====                ] 18% 8.7s164.7 MiB [====                ] 18% 8.5s164.7 MiB [====                ] 18% 8.4s164.7 MiB [====  ...
# Chromium 143.0.7499.4 (playwright build v1200) downloaded to /kaggle/working/web_parse_agent/ms-playwright/chromium-1200
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# (node:1085) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 2.3 MiB [                    ] 0% 0.0s2.3 MiB [                    ] 2% 1.9s2.3 MiB [=                   ] 4% 1.2s2.3 MiB [=                   ] 5% 1.4s2.3 MiB [==                  ] 9% 0.9s2.3 MiB [==                  ] 12% 0.9s2.3 MiB [====                ] 19% 0.6s2.3 MiB [=====               ] 26% 0.5s2.3 MiB [========            ] 40% 0.3s2.3 MiB [==========          ] 52% 0.2s2.3 MiB [================    ] 80% 0.1s2.3 MiB [====================] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /kaggle/working/web_parse_agent/ms-playwright/ffmpeg-1011
# Downloading Chromium Headless Shell 143.0.7499.4 (playwright build v1200) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1200/chromium-headless-shell-linux.zip
# (node:1096) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 109.7 MiB [                    ] 0% 0.0s109.7 MiB [                    ] 0% 147.9s109.7 MiB [                    ] 0% 154.7s109.7 MiB [                    ] 0% 377.0s109.7 MiB [                    ] 0% 323.1s109.7 MiB [                    ] 0% 421.2s109.7 MiB [                    ] 0% 375.5s109.7 MiB [                    ] 0% 341.8s109.7 MiB [                    ] 0% 316.6s109.7 MiB [                    ] 0% 296.9s109.7 MiB [                    ] 0% 281.2s109.7 MiB [                    ] 0% 257.3s109.7 MiB [                    ] 0% 255.3s109.7 MiB [                    ] 0% 245.8s109.7 MiB [                    ] 0% 237.8s109.7 MiB [                    ] 0% 229.8s109.7 MiB [                    ] 0% 214.7s109.7 MiB [                    ] 0% 201.2s109.7 MiB [                    ] 0% 180.7s109.7 MiB [                    ] 0% 165.1s109.7 MiB [                    ] 0% 157.0s109.7 MiB [                    ] 0% 146.1s109.7 MiB [                    ] 0% 137.0s109.7 MiB [                    ] 0% 132.3s109.7 MiB [                    ] 0% 125.1s109.7 MiB [                    ] 0% 117.4s109.7 MiB [                    ] 0% 110.8s109.7 MiB [                    ] 0% 104.0s109.7 MiB [                    ] 0% 96.5s109.7 MiB [                    ] 0% 90.1s109.7 MiB [                    ] 0% 83.0s109.7 MiB [                    ] 1% 77.5s109.7 MiB [                    ] 1% 73.1s109.7 MiB [                    ] 1% 68.3s109.7 MiB [                    ] 1% 64.3s109.7 MiB [                    ] 1% 60.8s109.7 MiB [                    ] 1% 56.8s109.7 MiB [                    ] 1% 52.8s109.7 MiB [                    ] 1% 49.1s109.7 MiB [                    ] 2% 45.6s109.7 MiB [                    ] 2% 42.4s109.7 MiB [                    ] 2% 39.2s109.7 MiB [=                   ] 2% 36.7s109.7 MiB [=                   ] 2% 34.0s109.7 MiB [=                   ] 3% 32.2s109.7 MiB [=                   ] 3% 29.4s109.7 MiB [=                   ] 3% 27.4s109.7 MiB [=                   ] 4% 25.4s109.7 MiB [=                   ] 4% 23.6s109.7 MiB [=                   ] 4% 21.9s109.7 MiB [=                   ] 5% 20.3s109.7 MiB [=                   ] 5% 18.7s109.7 MiB [=                   ] 6% 17.2s109.7 MiB [=                   ] 6% 16.2s109.7 MiB [=                   ] 7% 15.2s109.7 MiB [==                  ] 7% 14.7s109.7 MiB [==                  ] 7% 14.1s109.7 MiB [==                  ] 8% 13.5s109.7 MiB [==                  ] 8% 12.8s109.7 MiB [==                  ] 9% 11.9s109.7 MiB [==                  ] 9% 11.6s109.7 MiB [==                  ] 10% 11.3s109.7 MiB [==                  ] 10% 11.0s109.7 MiB [==                  ] 11% 10.7s109.7 MiB [==                  ] 11% 10.4s109.7 MiB [==                  ] 12% 9.9s109.7 MiB [===                 ] 12% 9.6s109.7 MiB [===                 ] 13% 9.2s109.7 MiB [===                 ] 13% 9.0s109.7 MiB [===                 ] 14% 8.8s109.7 MiB [===                 ] 14% 8.6s109.7 MiB [===                 ] 14% 8.4s109.7 MiB [===                 ] 15% 8.1s109.7 MiB [===                 ] 16% 7.8s109.7 MiB [===                 ] 16% 7.7s109.7 MiB [===                 ] 17% 7.5s109.7 MiB [===                 ] 17% 7.4s109.7 MiB [====                ] 17% 7.3s109.7 MiB [====                ] 18% 7.2s109.7 MiB [====                ] 18% 7.0s109.7 MiB [====                ] 19% 6.9s109.7 MiB [====                ] 19% 6.6s109.7 MiB [====                ] 20% 6.5s109.7 MiB [====                ] 21% 6.4s109.7 MiB [====                ] 21% 6.3s109.7 MiB [====                ] 22% 6.1s109.7 MiB [=====               ] 22% 5.9s109.7 MiB [=====               ] 23% 5.8s109.7 MiB [=====               ] 24% 5.7s109.7 MiB [=====               ] 24% 5.6s109.7 MiB [=====               ] 25% 5.5s109.7 MiB [=====               ] 26% 5.3s109.7 MiB [=====               ] 26% 5.2s109.7 MiB [=====               ] 27% 5.1s109.7 MiB [======              ] 27% 5.1s109.7 MiB [======              ] 28% 5.0s109.7 MiB [======              ] 2 ...
# Chromium Headless Shell 143.0.7499.4 (playwright build v1200) downloaded to /kaggle/working/web_parse_agent/ms-playwright/chromium_headless_shell-1200

# %%
# !pip uninstall -y openai
# !pip install "openai<2.0.0"
# Out:
# Found existing installation: openai 1.109.1
# Uninstalling openai-1.109.1:
#   Successfully uninstalled openai-1.109.1
# Collecting openai<2.0.0
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (2.12.5)
# Requirement already satisfied: sniffio in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /benchmarks/.venv/lib/python3.11/site-packages (from openai<2.0.0) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /benchmarks/.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0) (3.11)
# Requirement already satisfied: certifi in /benchmarks/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /benchmarks/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /benchmarks/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /benchmarks/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /benchmarks/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /benchmarks/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0) (0.4.2)
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unclecode-litellm 1.81.13 requires openai>=2.8.0, but you have openai 1.109.1 which is incompatible.
# langchain-openai 1.2.1 requires openai<3.0.0,>=2.26.0, but you have openai 1.109.1 which is incompatible.
# Successfully installed openai-1.109.1

# %%
import kaggle_benchmarks as kbench
from kaggle_benchmarks.messages import Message
from kaggle_benchmarks import actors
import inspect
from typing import Any, List, Optional
from langchain_core.language_models import BaseChatModel
from langchain_core.messages import BaseMessage, AIMessage, SystemMessage, HumanMessage
from langchain_core.outputs import ChatResult, ChatGeneration
from langchain_core.callbacks.manager import CallbackManagerForLLMRun

class KBenchLLMWrapper(BaseChatModel):
    kbench_llm: Any

    @property
    def _llm_type(self) -> str:
        return "kbench_llm"

    def _generate(
        self,
        messages: List[BaseMessage],
        stop: Optional[List[str]] = None,
        run_manager: Optional[CallbackManagerForLLMRun] = None,
        **kwargs: Any,
    ) -> ChatResult:
        system_content = None
        kbench_messages = []

        for m in messages:
            if isinstance(m, SystemMessage):
                system_content = m.content
            elif isinstance(m, HumanMessage):
                kbench_messages.append(Message(sender=actors.user, content=m.content))
            elif isinstance(m, AIMessage):
                kbench_messages.append(Message(sender=actors.assistant, content=m.content))

        sig = inspect.signature(self.kbench_llm.invoke)
        if 'system' in sig.parameters:
            response = self.kbench_llm.invoke(messages=kbench_messages, system=system_content)
        else:
            final_messages = [SystemMessage(content=system_content)] + messages if system_content else messages
            response = self.kbench_llm.invoke(final_messages)

        content = getattr(response, 'content', str(response))
        if isinstance(response, dict):
            content = response.get('content') or response.get('text') or str(response)

        return ChatResult(generations=[ChatGeneration(message=AIMessage(content=content))])

kbench_model = kbench.llms["openai/gpt-5.4-mini-2026-03-17"]
llm = KBenchLLMWrapper(kbench_llm=kbench_model)

# %%
import os
import sys
import json

from typing import Optional, Type
from pydantic import BaseModel

if '/kaggle/working/web_parse_agent' not in sys.path:
    sys.path.insert(0, '/kaggle/working/web_parse_agent')

from src.infrastructure.crawler import Crawl4AIAdapter
from src.agent.agents.extractor_agent import ExtractorAgent
from src.agent.agents.navigator_agent import NavigatorAgent
from src.agent.agents.aggregator_agent import AggregatorAgent
from src.agent.agents.crawler_agent import CrawlerAgent
from src.agent.graph import WebParsingGraph
from src.extractors.schemas.contact import ContactInfo


def run_parser(
        llm, 
        url: str,
        goal: str,
        mode: str = "flexible",
        schema: Optional[Type[BaseModel]] = None,
        max_depth: int = 2,
        max_pages: int = 5
) -> dict:

    navigator = NavigatorAgent(llm)
    extractor = ExtractorAgent(llm)
    aggregator = AggregatorAgent(llm)
    crawler = CrawlerAgent()

    graph = WebParsingGraph(
        navigator=navigator,
        extractor=extractor,
        aggregator=aggregator,
        crawler=crawler,
        max_depth=max_depth,
        max_pages=max_pages
    )

    print(f"Starting crawl: {url}")
    print(f"Goal: {goal}")
    print(f"Mode: {mode}, Max depth: {max_depth}, Max pages: {max_pages}")
    print("-" * 50)

    result = graph.run(
        start_url=url,
        goal=goal,
        mode=mode,
        schema=schema
    )

    print("-" * 50)
    print(f"Pages processed: {result['pages_processed']}")
    print(f"Visited: {result['visited_urls']}")

    return result

def main(llm):
    url = "https://jet.su/"

    print("EXAMPLE 1: Strict extraction with Pydantic schema")

    result = run_parser(
        llm=llm,
        url=url,
        goal="Extract key contact info",
        mode="strict",
        schema=ContactInfo,
        max_depth=3,
        max_pages=5
    )

    print("\nFinal result:")
    print(json.dumps(result['final_result'], indent=2, ensure_ascii=False))

    print("EXAMPLE 2: Flexible extraction")
    result = run_parser(
        llm=llm,
        url=url,
        goal="Extract strictly only minimal key information about company",
        mode="flexible",
        max_depth=3,
        max_pages=5
    )

    print("\nFinal result:")
    print(json.dumps(result['final_result'], indent=2, ensure_ascii=False))

main(llm)
# Out:
# ============================================================
# EXAMPLE 1: Flexible extraction
# ============================================================
# 2026-04-25 17:32:19,541 - BASE_AGENT - INFO - Initialized NavigatorAgent
# 2026-04-25 17:32:19,542 - BASE_AGENT - INFO - Initialized ExtractorAgent
# 2026-04-25 17:32:19,543 - BASE_AGENT - INFO - Initialized AggregatorAgent
# Starting crawl: https://jet.su/
# Goal: Extract strictly only minimal key information about company
# Mode: flexible, Max depth: 3, Max pages: 5
# --------------------------------------------------
# 2026-04-25 17:32:19,604 - NAVIGATOR_AGENT - INFO - Navigator: single candidate, returning https://jet.su/
# 2026-04-25 17:32:19,606 - CRAWLER_AGENT - INFO - Fetching: https://jet.su/
# [FETCH]... ↓ https://jet.su/                                                                                      |
# ✓ | ⏱: 5.09s
# [SCRAPE].. ◆ https://jet.su/                                                                                      |
# ✓ | ⏱: 0.13s
# [COMPLETE] ● https://jet.su/                                                                                      |
# ✓ | ⏱: 5.26s
# 2026-04-25 17:32:25,716 - CRAWLER_AGENT - INFO - Success: https://jet.su/ (36547 chars, 155 links)
# 2026-04-25 17:32:25,724 - FLEXIBLE_EXTRACTOR - INFO - Processing 4 chunk(s) for goal: Extract strictly only minimal key information about company
# 2026-04-25 17:32:31,705 - AGGREGATOR_AGENT - INFO - Aggregate flexible: 3 items
# 2026-04-25 17:32:35,788 - NAVIGATOR_AGENT - INFO - Selected: https://jet.su/about/
# 2026-04-25 17:32:35,789 - NAVIGATOR_AGENT - INFO - Navigator: LLM selected https://jet.su/about/
# 2026-04-25 17:32:35,791 - CRAWLER_AGENT - INFO - Fetching: https://jet.su/about/
# [FETCH]... ↓ https://jet.su/about/                                                                                |
# ✓ | ⏱: 4.93s
# [SCRAPE].. ◆ https://jet.su/about/                                                                                |
# ✓ | ⏱: 0.13s
# [COMPLETE] ● https://jet.su/about/                                                                                |
# ✓ | ⏱: 5.10s
# 2026-04-25 17:32:41,775 - CRAWLER_AGENT - INFO - Success: https://jet.su/about/ (35304 chars, 130 links)
# 2026-04-25 17:32:41,783 - FLEXIBLE_EXTRACTOR - INFO - Processing 4 chunk(s) for goal: Extract strictly only minimal key information about company
# 2026-04-25 17:32:46,854 - AGGREGATOR_AGENT - INFO - Aggregate flexible: 4 items
# 2026-04-25 17:32:49,996 - NAVIGATOR_AGENT - INFO - Selected: https://jet.su/about/history/
# 2026-04-25 17:32:49,997 - NAVIGATOR_AGENT - INFO - Navigator: LLM selected https://jet.su/about/history/
# 2026-04-25 17:32:49,999 - CRAWLER_AGENT - INFO - Fetching: https://jet.su/about/history/
# [FETCH]... ↓ https://jet.su/about/history/                                                                        |
# ✓ | ⏱: 3.71s
# [SCRAPE].. ◆ https://jet.su/about/history/                                                                        |
# ✓ | ⏱: 0.12s
# [COMPLETE] ● https://jet.su/about/history/                                                                        |
# ✓ | ⏱: 3.85s
# 2026-04-25 17:32:54,699 - CRAWLER_AGENT - INFO - Success: https://jet.su/about/history/ (46311 chars, 126 links)
# 2026-04-25 17:32:54,716 - FLEXIBLE_EXTRACTOR - INFO - Processing 6 chunk(s) for goal: Extract strictly only minimal key information about company
# 2026-04-25 17:33:05,634 - AGGREGATOR_AGENT - INFO - Aggregate flexible: 6 items
# 2026-04-25 17:33:13,554 - NAVIGATOR_AGENT - INFO - Selected: https://jet.su/about/directions/servis-i-autsorsing/
# 2026-04-25 17:33:13,554 - NAVIGATOR_AGENT - INFO - Navigator: LLM selected https://jet.su/about/directions/servis-i-autsorsing/
# 2026-04-25 17:33:13,555 - CRAWLER_AGENT - INFO - Fetching: https://jet.su/about/directions/servis-i-autsorsing/
# [FETCH]... ↓ https://jet.su/about/directions/servis-i-autsorsing/                                                 |
# ✓ | ⏱: 5.87s
# [SCRAPE].. ◆ https://jet.su/about/directions/servis-i-autsorsing/                                                 |
# ✓ | ⏱: 0.11s
# [COMPLETE] ● https://jet.su/about/directions/servis-i-autsorsing/                                                 |
# ✓ | ⏱: 6.01s
# 2026-04-25 17:33:20,506 - CRAWLER_AGENT - INFO - Success: https://jet.su/about/directions/servis-i-autsorsing/ (27964 chars, 136 links)
# 2026-04-25 17:33:20,514 - FLEXIBLE_EXTRACTOR - INFO - Processing 3 chunk(s) for goal: Extract strictly only minimal key information about company
# 2026-04-25 17:33:24,382 - AGGREGATOR_AGENT - INFO - Aggregate flexible: 1 items
# 2026-04-25 17:33:24,383 - AGGREGATOR_AGENT - INFO - Aggregate flexible: single item, no aggregation needed
# 2026-04-25 17:33:25,728 - NAVIGATOR_AGENT - INFO - No relevant URLs found
# 2026-04-25 17:33:25,729 - NAVIGATOR_AGENT - INFO - Navigator: LLM selected None
# 2026-04-25 17:33:25,731 - AGGREGATOR_AGENT - INFO - Aggregate flexible: 4 items
# --------------------------------------------------
# Pages processed: 4
# Visited: ['https://jet.su/', 'https://jet.su/about/', 'https://jet.su/about/history/', 'https://jet.su/about/directions/servis-i-autsorsing/']
#
# Final result:
# {
#   "company_name": "Инфосистемы Джет",
#   "short_name": "Джет",
#   "legal_name": "Акционерное общество \"Инфосистемы Джет\"",
#   "industry": "ИТ, консалтинг, информационная безопасность",
#   "company_type": "ИТ-интегратор",
#   "description": "Системная интеграция, внедрение ИТ-решений и реализация комплексных проектов",
#   "years_on_market": "30+ лет",
#   "founded_year": "1991",
#   "founded_in_industry_years": 25,
#   "employee_count": "2000+",
#   "employees": "1500",
#   "projects_per_year": "1000+ проектов в год",
#   "projects_total": 150,
#   "regions": "Россия и СНГ",
#   "website": "https://jetinfosystems.com",
#   "languages": [
#     "ru",
#     "en"
#   ],
#   "contacts_email": "digital@jet.su",
#   "email": "info@jet.su",
#   "phone": "+7 (495) 411-76-01",
#   "address": "127015, г. Москва, ул. Большая Новодмитровская, дом 14, строение 2, эт. 6, ком. 13, оф. 2.654.",
#   "ogrn": "1027700121195",
#   "inn": "7729058675",
#   "kpp": "771501001",
#   "okved": "62.02 Деятельность консультативная и работы в области компьютерных технологий",
#   "rankings": [
#     "ТОП-5 ИТ-компания",
#     "№ 1 на рынке ИТ-аутсорсинга (по версии TAdviser)",
#     "Лидер рынка (по версии RAEX, 2022)",
#     {
#       "source": "TAdviser",
#       "position": "№1",
#       "category": "ИТ-аутсорсинг"
#     },
#     {
#       "source": "TAdviser",
#       "position": "3",
#       "category": "крупнейшие поставщики ИТ в российской промышленности",
#       "revenue_growth_percent": 54
#     },
#     {
#       "source": "RAEX",
#       "position": "5",
#       "category": "крупнейшие ИТ-компании"
#     },
#     {
#       "source": "CNews",
#       "position": "3",
#       "category": "крупнейшие поставщики ИТ-услуг"
#     }
#   ],
#   "ranking": "входит в десятку крупнейших ИТ-компаний России и в ТОП-5 поставщиков ИТ-услуг",
#   "top_positions": [
#     "№1 на рынке ИТ-аутсорсинга в России",
#     "№1 в рейтинге крупнейших поставщиков инфраструктуры дата-центров",
#     "ТОП-3 в рейтинге крупнейших интеграторов в области защиты информации"
#   ],
#   "claims": [
#     "самый большой сервисный центр в России и СНГ",
#     "№1 в России по ИТ-аутсорсингу (TAdviser, 2022)",
#     "более 500 инженеров",
#     "средний SLA 98,5%",
#     "1600 точек присутствия в России"
#   ],
#   "directions": [
#     "Сервис и аутсорсинг",
#     "Инфраструктура 3.0 и гибридные облака",
#     "Информационная безопасность",
#     "Производственная безопасность",
#     "Интеллектуальные сети и сетевая экосистема",
#     "Цифровая трансформация и DevSecOps"
#   ],
#   "direction": "Сервис и аутсорсинг",
#   "activities": [
#     "ИТ-инфраструктура",
#     "информационная безопасность",
#     "консалтинг",
#     "разработка и внедрение ИТ-решений",
#     "Design and services for IT infrastructure, data centers, cloud infrastructure and control centers",
#     "Sale of software, databases and information security tools",
#     "Information security services including penetration testing, monitoring, incident response and protection implementation",
#     "Retail and wholesale supply, leasing and rental of hardware and IT infrastructure equipment"
#   ],
#   "key_activities": [
#     "техническая поддержка и партнерство с отечественными вендорами",
#     "разработка ИТ-решений и ПО",
#     "информационная безопасность",
#     "построение и модернизация ИТ-инфраструктуры",
#     "разработка платформ для контейнеризации и облаков",
#     "лаборатории и шоурумы для тестирования российских ИТ-решений"
#   ],
#   "services": [
#     "ИТ-инфраструктура",
#     "Информационная безопасность",
#     "Машинное обучение и искусственный интеллект",
#     "Разработка ПО и бизнес-приложения",
#     "Сервис и аутсорсинг",
#     "Сети и инженерная инфраструктура",
#     "Биометрия",
#     "Производственная безопасность",
#     "Собственные продукты в реестре российского ПО",
#     "Техническая поддержка оборудования и ПО",
#     "Администрирование и управление ИТ-инфраструктурой",
#     "ИТ-аутсорсинг: администрирование для крупного бизнеса",
#     "Аутсорсинг информационной безопасности - Jet CSIRT",
#     "Сервис и техподдержка инженерных систем ЦОД",
#     "Смартсорсинг в сфере разработки ПО",
#     "Центр компетенций SAP BASIS",
#     "Центр компетенций Zabbix",
#     "Центр компетенций VMware",
#     "Центр компетенций СУБД",
#     "Обслуживание рабочих мест пользователей",
#     "DevOps для ИТ-инфраструктуры"
#   ],
#   "topics": [
#     "кибербезопасность",
#     "ИИ",
#     "ИТ-инфраструктура",
#     "NGFW",
#     "цифровая трансформация"
#   ],
#   "projects": [
#     "Создание ИТ-инфраструктуры для новой АИС ОСАГО по принципам DevSecOps",
#     "В условиях непрерывного производства ГК «Русагро» создала бизнес-ориентированную систему информационной безопасности",
#     {
#       "client": "крупное металлургическое предприятие",
#       "type": "цифровой сервис",
#       "effect_rub_mln": 19.6
#     },
#     {
#       "client": "НЛМК",
#       "type": "сервис оптимизации потребления газа",
#       "savings": "несколько миллионов рублей ежемесячно"
#     }
#   ],
#   "notable_projects": [
#     "создание Jet RuLab для тестирования российских ИТ-решений",
#     "открытие шоурума VDI",
#     "внедрение омниканальной платформы для Beeline в Кыргызстане",
#     "запуск платформы управления контейнерами «Штурвал»",
#     "создание цифровой лаборатории охраны труда",
#     "переход к единому дата-центру для финансовой группы «Открытие»"
#   ],
#   "news": [
#     {
#       "date": "2026-04-03",
#       "title": "«Инфосистемы Джет» выводит на рынок собственный балансировщик нагрузки flxGATE"
#     },
#     {
#       "date": "2026-04-02",
#       "title": "«Инфосистемы Джет» завершила тестирование uNGFW 7.4.1"
#     },
#     {
#       "date": "2026-04-01",
#       "title": "«Инфосистемы Джет» зафиксировала увеличение спроса на экспертные сервисы ИБ на 71%"
#     },
#     {
#       "date": "2026-03-30",
#       "title": "«Инфосистемы Джет» представила обновленную методику тестирования NGFW 3.0"
#     }
#   ],
#   "history": [
#     {
#       "year": 2025,
#       "events": [
#         "Победа в премии RuPoR за проект CyberCamp 2024",
#         "Создание собственного ИБ-комьюнити Hello, CyberCamp"
#       ]
#     },
#     {
#       "year": 2024,
#       "events": [
#         "Премия Data Award за интеллектуальную систему планирования полевых работ с Русагро Тех",
#         "Победа проекта с ГК Детский мир на TAdviser IT Prize 2024",
#         "Собственное исследование рынка NGFW",
#         "Вошла в топ-5 работодателей по версии Хабр Карьеры",
#         "Вошла в топ-100 работодателей по версии HeadHunter",
#         "Признана самым привлекательным брендом среди ИТ-интеграторов по опросу ЭКОПСИ и Хабра"
#       ]
#     }
#   ],
#   "events": [
#     {
#       "name": "IT Elements",
#       "attendees_moscow": 2500,
#       "attendees_online": 6000,
#       "vendors": 30
#     },
#     {
#       "name": "CyberCamp 2024",
#       "viewers": 25000,
#       "solo_participants": 6000,
#       "teams": 138
#     },
#     {
#       "name": "CyberCamp 2023",
#       "viewers": 10000,
#       "teams": 100
#     }
#   ],
#   "partnerships": [
#     "М.Видео-Эльдорадо",
#     "Сколково",
#     "Газпромнефть-Гео",
#     "НЛМК",
#     "НПАО «Светогорский ЦБК»",
#     "OpenYard",
#     "Минтруд России",
#     "Сбербанк в Казахстане",
#     "Росбанк",
#     "Банк «Открытие»",
#     "Beeline в Кыргызстане"
#   ],
#   "products": [
#     "Штурвал",
#     "Jet RuLab",
#     "Jet CyberCamp",
#     "WMS собственной разработки"
#   ],
#   "website_sections": [
#     "Услуги и решения",
#     "Проекты",
#     "Центр экспертизы",
#     "О компании",
#     "Карьера",
#     "Контакты",
#     "Реквизиты"
#   ],
#   "careers_openings": 23,
#   "joined_association": "Ассоциация участников отрасли ЦОД",
#   "revenue_2019_rub": "31,1 млрд",
#   "revenue_growth_2019": "25%",
#   "warehouse_growth": "количество деталей на складе выросло более чем в 3 раза и превысило 28 тыс. ед. к концу 2023 года",
#   "founded_or_anniversary": "30 лет компании отмечено в 2021 году"
# }
#
# ============================================================
# EXAMPLE 2: Strict extraction with Pydantic schema
# ============================================================
# 2026-04-25 17:33:37,165 - BASE_AGENT - INFO - Initialized NavigatorAgent
# 2026-04-25 17:33:37,166 - BASE_AGENT - INFO - Initialized ExtractorAgent
# 2026-04-25 17:33:37,167 - BASE_AGENT - INFO - Initialized AggregatorAgent
# Starting crawl: https://jet.su/
# Goal: Extract key contact info
# Mode: strict, Max depth: 3, Max pages: 5
# --------------------------------------------------
# 2026-04-25 17:33:37,225 - NAVIGATOR_AGENT - INFO - Navigator: single candidate, returning https://jet.su/
# 2026-04-25 17:33:37,226 - CRAWLER_AGENT - INFO - Fetching: https://jet.su/
# [FETCH]... ↓ https://jet.su/                                                                                      |
# ✓ | ⏱: 3.85s
# [SCRAPE].. ◆ https://jet.su/                                                                                      |
# ✓ | ⏱: 0.12s
# [COMPLETE] ● https://jet.su/                                                                                      |
# ✓ | ⏱: 4.00s
# 2026-04-25 17:33:42,110 - CRAWLER_AGENT - INFO - Success: https://jet.su/ (36547 chars, 155 links)
# 2026-04-25 17:33:42,119 - STRICT_EXTRACTOR - INFO - Strict extraction 4 chunk for schema ContactInfo
# 2026-04-25 17:33:43,965 - STRICT_EXTRACTOR - INFO - Chunk 0: strict extraction OK
# 2026-04-25 17:33:45,894 - STRICT_EXTRACTOR - INFO - Chunk 1: strict extraction OK
# 2026-04-25 17:33:46,753 - STRICT_EXTRACTOR - INFO - Chunk 2: strict extraction OK
# 2026-04-25 17:33:47,885 - STRICT_EXTRACTOR - INFO - Chunk 3: strict extraction OK
# 2026-04-25 17:33:47,887 - AGGREGATOR_AGENT - INFO - Aggregate strict: 4 items for schema ContactInfo
# 2026-04-25 17:33:49,646 - NAVIGATOR_AGENT - INFO - Selected: https://jet.su/about/contacts/
# 2026-04-25 17:33:49,647 - NAVIGATOR_AGENT - INFO - Navigator: LLM selected https://jet.su/about/contacts/
# 2026-04-25 17:33:49,649 - CRAWLER_AGENT - INFO - Fetching: https://jet.su/about/contacts/
# [FETCH]... ↓ https://jet.su/about/contacts/                                                                       |
# ✓ | ⏱: 3.48s
# [SCRAPE].. ◆ https://jet.su/about/contacts/                                                                       |
# ✓ | ⏱: 0.09s
# [COMPLETE] ● https://jet.su/about/contacts/                                                                       |
# ✓ | ⏱: 3.60s
# 2026-04-25 17:33:54,092 - CRAWLER_AGENT - INFO - Success: https://jet.su/about/contacts/ (23398 chars, 124 links)
# 2026-04-25 17:33:54,098 - STRICT_EXTRACTOR - INFO - Strict extraction 3 chunk for schema ContactInfo
# 2026-04-25 17:33:54,988 - STRICT_EXTRACTOR - INFO - Chunk 0: strict extraction OK
# 2026-04-25 17:33:56,415 - STRICT_EXTRACTOR - INFO - Chunk 1: strict extraction OK
# 2026-04-25 17:33:57,264 - STRICT_EXTRACTOR - INFO - Chunk 2: strict extraction OK
# 2026-04-25 17:33:57,265 - AGGREGATOR_AGENT - INFO - Aggregate strict: 3 items for schema ContactInfo
# 2026-04-25 17:34:00,048 - NAVIGATOR_AGENT - INFO - No relevant URLs found
# 2026-04-25 17:34:00,049 - NAVIGATOR_AGENT - INFO - Navigator: LLM selected None
# 2026-04-25 17:34:00,050 - AGGREGATOR_AGENT - INFO - Aggregate strict: 2 items for schema ContactInfo
# --------------------------------------------------
# Pages processed: 2
# Visited: ['https://jet.su/', 'https://jet.su/about/contacts/']
#
# Final result:
# {
#   "phones": [
#     "+7 495 411-76-01",
#     "+7 495 411-76-03",
#     "+7 495 411-76-04",
#     "8 800 200-76-04"
#   ],
#   "emails": [
#     "digital@jet.su",
#     "info@jet.su",
#     "pr@jet.su"
#   ],
#   "addresses": [
#     "Москва",
#     "Владивосток",
#     "Краснодар",
#     "Санкт-Петербург",
#     "Екатеринбург",
#     "Самара"
#   ],
#   "social_links": [
#     "https://t.me/+DTFpOi9-ssxmYzRi",
#     "https://rutube.ru/channel/26045378/",
#     "https://habr.com/ru/company/jetinfosystems/profile/",
#     "https://hh.ru/employer/3095",
#     "https://jetinfosystems.com/?from=ru"
#   ],
#   "website": "https://jet.su",
#   "contact_form": "https://www.jet.su/about/contacts/",
#   "working_hours": null
# }
